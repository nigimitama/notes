# %% [markdown]
# # AI Coding

# %% [markdown]
# ### Plugins / Skills
#
# 特定領域の知識やMCPサーバーへの接続をまとめたもの。AIの性能を高める。
#
# #### 公式Plugins
#
#
#
# #### 非公式plugins
#
#
# - [awslabs/agent-plugins](https://github.com/awslabs/agent-plugins)：AWSの知識を与える
# - [caveman](https://github.com/juliusbrussee/caveman)：トークン数を節約する
# - [archify](https://github.com/tt-a1i/archify)：綺麗なアーキテクチャ図やシーケンス図を描く
