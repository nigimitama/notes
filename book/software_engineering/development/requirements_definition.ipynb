# %% [markdown]
# # 要件定義

# %% [markdown]
# [システムは「動く」だけでは 足りない - 非機能要件・分散システム・トレードオフの基礎 - Speaker Deck](https://speakerdeck.com/nwiizo/sisutemuha-dong-ku-dakedeha-zu-rinai-fei-ji-neng-yao-jian-fen-san-sisutemutoredoohunoji-chu)

# %% [markdown]
# ## 要件と要求の定義
#
# [要件定義とはそもそも何か - Speaker Deck](https://speakerdeck.com/haru860/yao-jian-ding-yi-tohasomosomohe-ka)
#
# 要件とは
#
# - 要求（Requirement）：製品またはプロセスの運用・機能・設計上の特性を識別する文
# - 要件：要求のうち、特に合理性や形式性を伴うことを強調するときに「要件」を用いる
#     - 機能要件：ソフトウェア開発時に定義される要件のうち、機能に関するもの。たとえば扱えるデータのタイプ、処理の内容、画面表示や出力の形式など
#     - 非機能要件：信頼性・セキュリティ・拡張性・運用性など
#
# 要件定義TIPS
#
# - 業務やユースケースを理解してから開発しよう
# - ユースケース図だと情報が少ないので業務フロー図で表すとよい

# %% [markdown]
# ## 関連: ドメイン駆動設計
#
# 要件（特に複雑な業務ルール）をモデルに落とし込む設計手法として [ドメイン駆動設計（DDD）](../design/domain_driven_design/index.ipynb) を参照。
