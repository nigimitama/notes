# %% [markdown]
# # Bayesian IRT

# %% [markdown]
# ## 理論

# %% [markdown]
# ### 事前分布の選択
#
# Natesan, P., Nandakumar, R., Minka, T., & Rubright, J. D. (2016). Bayesian prior choice in IRT estimation using MCMC and variational Bayes. Frontiers in psychology, 7, 1422. https://doi.org/10.3389/fpsyg.2016.01422
#
# - 1PLM, 2PLMでの事前分布
# - 変分推定の結果を事前分布に使う

# %% [markdown]
# ## 実装

# %% [markdown]
# ## 1PLM/2PLM
#
# 実装例：[jurader/irt_pystan_numpyro](https://github.com/jurader/irt_pystan_numpyro)（stanとNumPyroの速度比較をした論文の実装）

# %% [markdown]
# ### BUGS
#
# [Curtis, S. M. (2010). BUGS code for item response theory. Journal of Statistical Software, 36, 1-34.](https://www.jstatsoft.org/article/view/v036c01)
#
# - BUGS（Stanとやや似てるギブスサンプラー）での実装例
# - 様々なモデルが載っている：2PLM, 3PLM, GRM, GPCM, Testlet model, Generalized testlet model

# %% [markdown]
# ### Stan
#
# [[1905.09501] Bayesian Item Response Modeling in R with brms and Stan](https://arxiv.org/abs/1905.09501)
#
# - RでStanを簡単に書ける{brms}パッケージの紹介論文

# %% [markdown]
# ## 参考
#
# - [しなやかな項目反応モデル - Speaker Deck](https://speakerdeck.com/ytake2/sinayakanaxiang-mu-fan-ying-moderu?slide=3)
# - Albert, J. (2015). Introduction to Bayesian item response modelling. International Journal of Quantitative Research in Education, 2(3/4), 178. https://doi.org/10.1504/ijqre.2015.071732
# - Fox J.-P. (2010). [Bayesian Item Response Modeling: Theory and Applications](https://link.springer.com/book/10.1007/978-1-4419-0742-4). New York, NY: Springer.
