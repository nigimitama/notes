# %% [markdown]
# # IRTが実装できるパッケージ

# %% [markdown]
# ## ベイズ推定
#
# Stan, NumPyroなどの確率プログラミング言語や、それらのラッパーであるPyMC, BayesianInferenceなどを使う

# %% [markdown]
# ### 参考
#
# - [Python/NumPyroで実装する項目反応理論と垂直尺度化 - ドワンゴ教育サービス開発者ブログ](https://blog.nnn.dev/entry/2025/10/16/110000)
#
# :::{card}
#
# Nishio, M., Ota, E., Matsuo, H., Matsunaga, T., Miyazaki, A., & Murakami, T. (2023). [Comparison between pystan and numpyro in Bayesian item response theory: evaluation of agreement of estimated latent parameters and sampling performance](https://doi.org/10.7717/peerj-cs.1620). PeerJ Computer Science, 9, e1620.
#
# 1PLM, 2PLMを実装し、多くの場合でPyStanよりNumPyroのほうが速かったとのこと
#
# :::
