# %% [markdown]
# # 不動産の経済学
#
# 不動産×経済学っぽいトピックをまとめたもの

# %% [markdown]
# :::{toc}
# :context: children
# :depth: 1
# :::

# %% [markdown]
# [Journal of Housing Economics | ScienceDirect.com by Elsevier](https://www.sciencedirect.com/journal/journal-of-housing-economics)
