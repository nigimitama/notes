# %% [markdown]
# # 拼音・発音

# %% [markdown]
# ## 声調
#
# ピンインの点は発音の高低の変化を表している
#
# | 声調   | 拼音 | 意味               | 声調の説明         |
# | ------ | ---- | ------------------ | ------------------ |
# | 第一声 | mā   | 母（お母さん）     | 高く平らな音       |
# | 第二声 | má   | 麻（麻・痺れ）     | 上がる音（疑問風） |
# | 第三声 | mǎ   | 馬                 | くぼむような音     |
# | 第四声 | mà   | 罵る               | 下がる強い音       |
# | 軽声   | ma   | ～か？（疑問助詞） | 軽く短く発音       |

# %% [markdown]
# ほぼmaだが声調の違いで文章が作れる
#
# :::{card}
#
# > 妈妈骑马，马慢，妈妈骂马。
# >
# > Māma qí mǎ, mǎ màn, māma mà mǎ.
#
# お母さんが馬に乗っていて、馬が遅かったので、お母さんは馬を叱った。
#
# [Famous Chinese Tongue Twister 妈妈骑马 mama qi ma #ChineseTongueTwisters #汉语绕口令 #中国語の一番有名な早口言葉 - YouTube](https://www.youtube.com/watch?v=xigEP6gMqzc&ab_channel=YoupengChinese)
# :::

# %% [markdown]
# :::{card}
#
# 「ü（ウムラウト付きu）」は「i」と似た舌の位置で、唇は「u」の形にする → 日本語にない音なので要注意
#
# 「i」「u」「ü」は、前に子音があると音が変化する場合がある（例：zhi, chi, shi の i は特殊音 \[ɿ\]）
#
# :::

# %% [markdown]
# ## 母音
#
# ### 単母音（単純母音）
#
# | 拼音 | IPA           | カタカナ発音例   | 備考                            | 単語の例（日本語訳）                        |
# | ---- | ------------- | ---------------- | ------------------------------- | ------------------------------------------- |
# | a    | [a]           | アー             | 口を大きく開ける                | **妈 mā**（お母さん）                       |
# | o    | [ɔ]           | オー             | 英語の "awe" に近い音           | **我 wǒ**（私）                             |
# | e    | [ɤ] / [ə]     | ウァ／オー       | 無声音「うあ」、曖昧母音        | **饿 è**（空腹）、**的 de**（の）           |
# | i    | [i], [ɿ], [ʅ] | イー／ズゥ／シゥ | 子音により異なる（例：si, zhi） | **你 nǐ**（あなた）、**是 shì**（〜である） |
# | u    | [u]           | ウー             | 唇を丸めて前に突き出す          | **书 shū**（本）                            |
# | ü    | [y]           | ユー             | 唇を丸めた「イ」、日本語にない  | **女 nǚ**（女性）, 律师 Lǜshī （弁護士）       |
#
#
# ### 複合母音
#
#
# | 拼音 | IPA  | カタカナ発音例 | 備考                     | 単語の例（日本語訳） |
# | ---- | ---- | -------------- | ------------------------ | -------------------- |
# | ai   | [aɪ̯] | アイ           | 英語 "eye" に近い音      | **爱 ài**（愛）      |
# | ei   | [eɪ̯] | エイ           | 英語 "way" に近い音      | **北 běi**（北）     |
# | ao   | [ɑʊ̯] | アオ           | 「ア」と「オ」の中間     | **好 hǎo**（良い）   |
# | ou   | [oʊ̯] | オウ           | 「オー」と「ウー」の中間 | **走 zǒu**（歩く）   |
# | ia   | [i̯a] | イア           | i + a                    | **家 jiā**（家）     |
# | ie   | [i̯ɛ] | イエ           | i + e                    | **也 yě**（〜も）    |
# | ua   | [u̯a] | ウア           | u + a                    | **花 huā**（花）     |
# | uo   | [u̯ɔ] | ウオ           | u + o                    | **我 wǒ**（私）      |
# | üe   | [y̯œ] | ユエ           | ü + e、日本語にない      | **月 yuè**（月）     |
# | er   | [ɑɻ] | アール         | r音を含む独立した音      | **儿 ér**（子供）    |
#
#
#
# ### 鼻母音（鼻に抜ける音）
#
#
# | 拼音 | IPA   | カタカナ発音例     | 備考                         | 単語の例（日本語訳）  |
# | ---- | ----- | ------------------ | ---------------------------- | --------------------- |
# | an   | [an]  | アン               | nの音をしっかり出す          | **安 ān**（安全）     |
# | en   | [ən]  | エン               | 曖昧母音＋n                  | **很 hěn**（とても）  |
# | in   | [in]  | イン               | i + n                        | **新 xīn**（新しい）  |
# | un   | [u̯ən] | ウン               | u + n                        | **问 wèn**（尋ねる）  |
# | ün   | [y̯n]  | ユン               | ü + n、日本語にない          | **云 yún**（雲）      |
# | ang  | [ɑŋ]  | アン（鼻に抜ける） | ng音、口を開けて鼻を響かせる | **帮 bāng**（助ける） |
# | eng  | [əŋ]  | エン（鼻に抜ける） | 曖昧母音＋ng                 | **冷 lěng**（冷たい） |
# | ing  | [iŋ]  | イン（鼻に抜ける） | i + ng                       | **听 tīng**（聞く）   |
# | ong  | [ʊŋ]  | オン（鼻に抜ける） | o + ng、唇を丸めて発音       | **中 zhōng**（中）    |

# %% [markdown]
# ## 参考
#
# - [中国語の発音｜ウェブ音声サービス | ベーシッククラウン中日・日中辞典｜三省堂](https://dictionary.sanseido-publ.co.jp/vod/bccj/)
