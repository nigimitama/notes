# %% [markdown]
# # 貪欲法

# %% [markdown]
# ## 応用例
#
# 線形探索で硬貨を順番に調べながら、貪欲法で最小枚数を求める例
#
# Q. $X$円の金額を日本の硬貨で支払うとき、必要な硬貨の最小枚数は？

# %%
coins = [500, 100, 50, 10, 5, 1] # 硬貨の種類

X = 873 # 例：873円を払いたい
total = 0
for coin in coins:
    count = X // coin  # その硬貨を何枚使えるか
    if count > 0:
        total += count
        X %= coin      # 残りの金額を更新

print(total)
# Out:
# 10
