# %% [markdown]
# # Inertia.js (inertia-rails)

# %% [markdown]
# https://inertiajs.com/

# %% [markdown]
# RailsでReactのようなモダンなフロントエンドを使えるようになるアダプタ的なライブラリ。
#
# SPAになるわけではなく、MPA

# %% [markdown]
# ## リンク

# %% [markdown]
# - https://inertiajs.com/
# - [Inertia.js (inertia-rails) を触っているので所感を書いておく - id:onk のはてなブログ](https://onk.hatenablog.jp/entry/2026/03/31/052250)
