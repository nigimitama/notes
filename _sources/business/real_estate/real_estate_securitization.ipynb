# %% [markdown]
# # 不動産証券化
#
# 不動産を証券として分割して小口化することで流動性（売買しやすさ）を増やす方法。

# %% [markdown]
# ## 証券化不動産の仕組み
#
#
#
# - [不動産証券化とは？｜不動産証券化とは？｜不動産証券化協会 -ARES-](https://www.ares.or.jp/learn/explanation/)

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# [mlit.go.jp/common/001059020.pdf](https://www.mlit.go.jp/common/001059020.pdf)
