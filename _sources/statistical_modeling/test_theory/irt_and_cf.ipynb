# %% [markdown]
# # IRTと協調フィルタリング

# %% [markdown]
# Bergner ら（2012）“Machine-Learning Item Response Theory”
# 学習者×設問の正誤データを、CFの評価（予測精度・CV）でモデル選択する、という立場。
# https://eric.ed.gov/?id=ED537194
#
#
# Bergner / Halpin / Vie（2023）“Multidimensional IRT in the Style of Collaborative Filtering”
# タイトル通り「CF流のMIRT」。高次元・疎行列を前提に、JML + CV で運用する話。
# [Multidimensional Item Response Theory in the Style of Collaborative Filtering | Psychometrika | Cambridge Core](https://doi.org/10.1007/s11336-021-09788-9)

# %% [markdown]
# ### 多次元IRT（MIRT）≒ ロジスティックMF（低ランク）
#
# [Logistic Matrix Factorization for Implicit Feedback Data](https://web.stanford.edu/~rezab/nips2014workshop/submits/logmat.pdf)
