# %% [markdown]
# # 因果探索
#
# :::{tableofcontents}
# :::

# %% [markdown]
# ## 参考文献
#
# - [Glymour, C., Zhang, K., & Spirtes, P. (2019). Review of causal discovery methods based on graphical models. Frontiers in genetics, 10, 524.](https://www.frontiersin.org/journals/genetics/articles/10.3389/fgene.2019.00524/full)
# - [Hasan, U., Hossain, E., & Gani, M. O. (2023). A survey on causal discovery methods for iid and time series data. arXiv preprint arXiv:2303.15027.](https://arxiv.org/abs/2303.15027)
