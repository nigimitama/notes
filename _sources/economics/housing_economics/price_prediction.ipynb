# %% [markdown]
# # 価格予測

# %% [markdown]
# ## LLMの活用
#
# ### GeoLLM
#
# 地理情報をLLMで生成し、追加の特徴量とする
#
# ### LLMによる価格予測
#
# - blog: [不動産価値推定におけるLLMの活用法について](https://zenn.dev/mtec_blog/articles/0b6538eaec8721)
# - proceedings: [不動産価値推定における大規模言語モデルの活用可能性に関する検証](https://www.jstage.jst.go.jp/article/pjsai/JSAI2024/0/JSAI2024_2I5GS1002/_article/-char/ja)
