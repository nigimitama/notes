# %% [markdown]
# # 広告

# %% [markdown]
# :::{card} [今や広告は目立たないほうがいい？　今年も行われた「スマホゲームマーケの『嘘』」を紹介するセッションレポート［CEDEC 2024］](https://www.4gamer.net/games/999/G999905/20240823039/)
#
# - サードパーティの計測ツールが人間の肌感と違う場合に注意
#     - ひどいものはゲームをインストールしたあとに表示した広告の成果でインストールした扱いになってたりする → **広告が実際より大幅に過大評価されている**
#
# :::
